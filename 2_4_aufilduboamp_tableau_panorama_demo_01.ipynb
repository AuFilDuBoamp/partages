# %% [markdown]
# <a href="https://colab.research.google.com/github/AuFilDuBoamp/partages/blob/main/2_4_aufilduboamp_tableau_panorama_demo_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://www.aufilduboamp.com/partages/csv/aufilduboamp_csv_panorama_boamp_2023_03.csv', sep=';', low_memory=False)

# %%
df.head().T
# Out:
#                                                                                     0  \
# P_01_annoncelie                                                                   NaN
# P_02_annoncereferenceschemav110                                                   NaN
# P_03_annoncesanterieuresschemav110                                                NaN
# P_04_codedepartement                                                   76,27,80,14,60
# P_05_codedepartementprestation                                                    NaN
# P_06_criteres                                                sociaux,environnementaux
# P_07_datefindiffusion                                                      2023-04-30
# P_08_datelimitereponse                                                            NaN
# P_09_dateparution                                                          2023-03-01
# P_10_dc                                                                       184,207
# ...
