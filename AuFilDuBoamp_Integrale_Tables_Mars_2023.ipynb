# %% [markdown]
# <a href="https://colab.research.google.com/github/AuFilDuBoamp/partages/blob/main/AuFilDuBoamp_Integrale_Tables_Mars_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Retrouvez dans ce Notebook (Python) l'intégrale des Tables AuFilDuBoamp
# # de Mars 2023 en libre accès

# %%
import pandas as pd

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/A_00_PANORAMA_2023_03_AP.csv', sep=';', low_memory=False, nrows=3)
# Out:
#    P_01_Annoncelie  P_02_Annoncereferenceschemav110  \
# 0              NaN                              NaN
# 1              NaN                              NaN
# 2              NaN                              NaN
#
#    P_03_Annoncesanterieuresschemav110  P_04_Codedepartement  \
# 0                                 NaN                    34
# 1                                 NaN                    36
# 2                                 NaN                    34
#
#    P_05_Codedepartementprestation     P_06_Criteres P_07_Datefindiffusion  \
# 0                             NaN  environnementaux            2023-04-14
# 1                             NaN               NaN            2023-03-31
# 2                             NaN  environnementaux            2023-04-14
#
#       P_08_Datelimitereponse P_09_Dateparution P_10_Dc  ... P_29_Sourceschema  \
# 0                        NaN        2023-03-01     102  ...              None
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/B_01_ANNONCESANTERIEURES_2023_03_AP.csv', sep=';', low_memory=False, nrows=3)
# Out:
#                             B_01_Annoncesanterieures B_DATEPARUTION   B_IDWEB  \
# 0  {'REFERENCE': {'IDWEB': '22-99363', 'TYPE_AVIS...     2023-03-01  23-14284
# 1  {'REFERENCE': {'IDWEB': '22-99363', 'TYPE_AVIS...     2023-03-01  23-14284
# 2  {'REFERENCE': {'IDWEB': '22-128219', 'TYPE_AVI...     2023-03-01  23-22248
#
#                                            B_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-14284
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-14284
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-22248
#
#                B_01_01_Annoncesanterieures_Reference  \
# 0  {'IDWEB': '22-99363', 'TYPE_AVIS': {'FAMILLE':...
# 1  {'IDWEB': '22-99363', 'TYPE_AVIS': {'FAMILLE':...
# 2  {'IDWEB': '22-128219', 'TYPE_AVIS': {'FAMILLE'...
#
#     B_01_02_Annoncesanterieures_Referencepublication  \
# 0  {'PUBLICATION_ELECTRONIQUE': {'DATE_PUBLICATIO...
# 1  {'PUBLICATION_JOUE': {'ANNEE': '2022', 'NUM_PA...
# 2  {'PUBLICATION_ELECTRONIQUE': {'DATE_PUBLICATIO...
#
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_01_IDENTITE_2023_03_AP.csv', sep=';', low_memory=False, nrows=3)
# Out:
#   D01_IDWEB D01_DATEPARUTION  \
# 0  23-11072       2023-03-01
# 1  23-11678       2023-03-01
# 2  23-11786       2023-03-01
#
#                                          D01_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-11072
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-11678
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-11786
#
#                                        D_01_Identite  \
# 0  {'DENOMINATION': 'Montpellier Méditerranée Mét...
# 1  {'DENOMINATION': 'CHATEAUROUX METROPOLE', 'TYP...
# 2  {'DENOMINATION': 'Montpellier Méditerranée Mét...
#
#   D_01_01_Identite_Adjudicateurnuts           D_01_02_Identite_Adresse  \
# 0                             FRJ13  50, Place Zeus , Lieu dit CS39556
# 1                               NaN                                NaN
# 2                             FRJ13  50, Place Zeus , Lieu dit CS39556
#
#    D_01_03_Identite_Agitpourautrecomptenon  \
# 0                                     True
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_02_TYPEORGANISME_2023_03_AP.csv', sep=';', low_memory=False, nrows=3)
# Out:
#   D02_IDWEB D02_DATEPARUTION  \
# 0  23-22634       2023-03-01
# 1  23-24255       2023-03-01
# 2  23-27155       2023-03-01
#
#                                          D02_URLAVIS D_02_Typeorganisme  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-22634    {'COMMUNE': ''}
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-24255      {'AUTRE': ''}
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-27155      {'AUTRE': ''}
#
#    D_02_02_Typeorganisme_Commune  D_02_08_Typeorganisme_Region  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
#
#    D_02_03_Typeorganisme_Departement  D_02_05_Typeorganisme_Ept  \
# 0                                NaN                        NaN
# 1                                NaN                        NaN
# 2                                NaN                        NaN
#
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_03_TYPEPOUVOIRADJUDICATEUR_2023_03_AP.csv', sep=';', low_memory=False, nrows=3)
# Out:
#   D03_IDWEB D03_DATEPARUTION  \
# 0  23-11072       2023-03-01
# 1  23-11786       2023-03-01
# 2  23-14284       2023-03-01
#
#                                          D03_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-11072
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-11786
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-14284
#
#              D_03_Typepouvoiradjudicateur  \
# 0                {'ORG_DROIT_PUBLIC': ''}
# 1                {'ORG_DROIT_PUBLIC': ''}
# 2  {'AUTRE': 'collectivité territoriale'}
#
#    D_03_06_Typepouvoiradjudicateur_Minautoritenationale  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    D_03_03_Typepouvoiradjudicateur_Autotriteregional  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_04_ACTIVITEPRINCIPALE_2023_03_AP.csv', sep=';', low_memory=False, nrows=3)
# Out:
#   D04_IDWEB D04_DATEPARUTION  \
# 0  23-11072       2023-03-01
# 1  23-11786       2023-03-01
# 2  23-14284       2023-03-01
#
#                                          D04_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-11072
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-11786
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-14284
#
#                              D_04_Activiteprincipale  \
# 0  {'POUVOIR_ADJUDICATEUR': {'ACT_SERV_ADM_PUB': ...
# 1  {'POUVOIR_ADJUDICATEUR': {'ACT_SERV_ADM_PUB': ...
# 2  {'POUVOIR_ADJUDICATEUR': {'ACT_SERV_ADM_PUB': ...
#
#   D_04_02_Activiteprincipale_Pouvoiradjudicateur  \
# 0                       {'ACT_SERV_ADM_PUB': ''}
# 1                       {'ACT_SERV_ADM_PUB': ''}
# 2                       {'ACT_SERV_ADM_PUB': ''}
#
#       D_04_01_Activiteprincipale_Entiteadjudicatrice  \
# 0  {'ACT_AEROPORT': None, 'ACT_PORT': None, 'AUTR...
# 1  {'ACT_AEROPORT': None, 'ACT_PORT': None, 'AUTR...
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_05_OBJET_2023_03_AP.csv', sep=';', low_memory=False, nrows=3)
# Out:
#   D05_DATEPARUTION D05_IDWEB  \
# 0       2023-03-12  23-32913
# 1       2023-03-12  23-32913
# 2       2023-03-12  23-32913
#
#                                          D05_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-32913
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-32913
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-32913
#
#                            D_05_01_Objet_Accordcadre  D_05_02_Objet_Ampnon  \
# 0  {'VALEUR': None, 'NB_PARTICIPANTS': None, 'VAL...                   NaN
# 1  {'VALEUR': None, 'NB_PARTICIPANTS': None, 'VAL...                   NaN
# 2  {'VALEUR': None, 'NB_PARTICIPANTS': None, 'VAL...                   NaN
#
#    D_05_03_Objet_Ampoui                       D_05_04_Objet_Aviscorrespond  \
# 0                   NaN  {'AVIS_PERIODIQUE_INDICATIF': '', 'SYSTEME_QUA...
# 1                   NaN  {'AVIS_PERIODIQUE_INDICATIF': '', 'SYSTEME_QUA...
# 2                   NaN  {'AVIS_PERIODIQUE_INDICATIF': '', 'SYSTEME_QUA...
#
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_06_PROCEDURE_2023_03_AP.csv', sep=';', low_memory=False, nrows=3)
# Out:
#   D06_IDWEB D06_DATEPARUTION  \
# 0  23-27213       2023-03-01
# 1  23-27213       2023-03-01
# 2  23-27213       2023-03-01
#
#                                          D06_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-27213
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-27213
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-27213
#
#                                       D_06_Procedure  \
# 0  {'TYPE_PROCEDURE': {'RESTREINT': ''}, 'NB_CAND...
# 1  {'TYPE_PROCEDURE': {'RESTREINT': ''}, 'NB_CAND...
# 2  {'TYPE_PROCEDURE': {'RESTREINT': ''}, 'NB_CAND...
#
#   D_06_24_Procedure_Typeprocedure  \
# 0               {'RESTREINT': ''}
# 1               {'RESTREINT': ''}
# 2               {'RESTREINT': ''}
#
#                D_06_10_Procedure_Criteresattribution  \
# 0  {'CRITERES_LIBRE': "Hiérarchisation selon les ...
# 1  {'CRITERES_LIBRE': "Hiérarchisation selon les ...
# 2  {'CRITERES_LIBRE': "Hiérarchisation selon les ...
#
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_07_PUBLICATIONANTERIEURE_2023_03_AP.csv', sep=';', low_memory=False, nrows=3)
# Out:
#   D07_IDWEB D07_DATEPARUTION  \
# 0  23-14284       2023-03-01
# 1  23-14847       2023-03-01
# 2  23-20847       2023-03-01
#
#                                          D07_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-14284
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-14847
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-20847
#
#                           D_07_Publicationanterieure  \
# 0  {'OUI': '', 'REFERENCE_PUBLICATION': {'PUBLICA...
# 1  {'OUI': '', 'REFERENCE_PUBLICATION': {'PUBLICA...
# 2  {'OUI': '', 'REFERENCE_PUBLICATION': {'PUBLICA...
#
#    D_07_01_Publicationanterieure_Non  D_07_02_Publicationanterieure_Oui  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
#
#   D_07_03_Publicationanterieure_Referencepublication  \
# 0  {'PUBLICATION_JOUE': {'NATURE': {'AVIS_MARCHE'...
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_08_ATTRIBUTION_2023_03_AP.csv', sep=';', low_memory=False, nrows=3)
# Out:
#   D08_IDWEB D08_DATEPARUTION  \
# 0  23-26865       2023-03-01
# 1  23-26865       2023-03-01
# 2  23-26934       2023-03-01
#
#                                          D08_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-26865
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-26865
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-26934
#
#                                     D_08_Attribution  \
# 0  {'ATTRIBUE_PAR_LOTS_MARCHES': '', 'DECISION': ...
# 1  {'ATTRIBUE_PAR_LOTS_MARCHES': '', 'DECISION': ...
# 2  {'ATTRIBUE_PAR_LOTS_MARCHES': '', 'DECISION': ...
#
#    D_08_01_Attribution_Attribuecomportelotinfructueux  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    D_08_02_Attribution_Attribueparlotsmarches  \
# 0                                        True
# 1                                        True
# 2                                        True
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_09_RECTIF_2023_03_AP.csv', sep=';', low_memory=False, nrows=3)
# Out:
#   D09_IDWEB D09_DATEPARUTION  \
# 0  23-25540       2023-03-01
# 1  23-25540       2023-03-01
# 2  23-25540       2023-03-01
#
#                                          D09_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-25540
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-25540
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-25540
#
#                                          D_09_Rectif  \
# 0  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 1  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 2  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
#
#                      D_09_01_Rectif_Annonceanterieur  \
# 0  {'REFERENCE': {'IDWEB': '23-10253', 'TYPE_AVIS...
# 1  {'REFERENCE': {'IDWEB': '23-10253', 'TYPE_AVIS...
# 2  {'REFERENCE': {'IDWEB': '23-10253', 'TYPE_AVIS...
#
#    D_09_02_Rectif_Infocomplementaire  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
#
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_10_ANNULATION_2023_03_AP.csv', sep=';', low_memory=False, nrows=3)
# Out:
#   D10_IDWEB D10_DATEPARUTION  \
# 0  23-27989       2023-03-01
# 1  23-31239       2023-03-08
# 2  23-35362       2023-03-16
#
#                                          D10_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-27989
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-31239
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-35362
#
#                                      D_10_Annulation  \
# 0  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 1  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 2  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
#
#                  D_10_01_Annulation_Annonceanterieur  \
# 0  {'REFERENCE': {'IDWEB': '23-9111', 'TYPE_AVIS'...
# 1  {'REFERENCE': {'IDWEB': '23-29942', 'TYPE_AVIS...
# 2  {'REFERENCE': {'IDWEB': '23-35154', 'TYPE_AVIS...
#
#                             D_10_02_Annulation_Motif  \
# 0  Des erreurs ont été constatées mettant en caus...
# 1  Erreur dans la dénomination du marché: inférie...
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_11_CONDITIONDELAI_2023_03_AP.csv', sep=';', low_memory=False, nrows=3)
# Out:
#   D11_IDWEB D11_DATEPARUTION  \
# 0  23-11072       2023-03-01
# 1  23-11678       2023-03-01
# 2  23-11786       2023-03-01
#
#                                          D11_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-11072
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-11678
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-11786
#
#                                  D_11_Conditiondelai  \
# 0  {'RECEPT_OFFRES': '2023-04-14T12:00:00+01:00',...
# 1     {'RECEPT_OFFRES': '2023-03-31T12:00:00+01:00'}
# 2  {'RECEPT_OFFRES': '2023-04-14T12:00:00+01:00',...
#
#   D_11_01_Conditiondelai_Dureesystemequalification  \
# 0           {'DATE_DEBUT': None, 'DATE_FIN': None}
# 1           {'DATE_DEBUT': None, 'DATE_FIN': None}
# 2           {'DATE_DEBUT': None, 'DATE_FIN': None}
#
#    D_11_02_Conditiondelai_Limiteenvoiinvit  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
#
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_12_CONDITIONRELATIVEMARCHE_2023_03_AP.csv',
            sep=';', low_memory=False, nrows=3, usecols=lambda x: x not in ['D_12_Conditionrelativemarche'])
# Out:
#   D12_IDWEB D12_DATEPARUTION  \
# 0  23-11072       2023-03-01
# 1  23-11678       2023-03-01
# 2  23-11786       2023-03-01
#
#                                          D12_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-11072
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-11678
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-11786
#
#    D_12_01_Conditionrelativemarche_Autresconditionspartnon  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    D_12_02_Conditionrelativemarche_Autresconditionspartoui  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    D_12_03_Conditionrelativemarche_Cautionnement  \
# 0                                            NaN
# 1                                            NaN
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_13_CONDITIONPARTICIPATION_2023_03_AP.csv', sep=';', low_memory=False, nrows=3)
# Out:
#   D13_IDWEB D13_DATEPARUTION  \
# 0  23-22634       2023-03-01
# 1  23-22634       2023-03-01
# 2  23-27155       2023-03-01
#
#                                          D13_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-22634
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-22634
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-27155
#
#                          D_13_Conditionparticipation  \
# 0  {'JUSTIFICATIFS_CANDIDAT': {'P': ['Autres rens...
# 1  {'JUSTIFICATIFS_CANDIDAT': {'P': ['Autres rens...
# 2  {'JUSTIFICATIFS_CANDIDAT': {'P': ["Documents à...
#
#    D_13_01_Conditionparticipation_Capeco  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
#
#    D_13_02_Conditionparticipation_Capecomarchenon  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
#
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_10_ANNULATION_2023_03_AP.csv', sep=';', low_memory=False, nrows=10)
# Out:
#   D10_IDWEB D10_DATEPARUTION  \
# 0  23-27989       2023-03-01
# 1  23-31239       2023-03-08
# 2  23-35362       2023-03-16
#
#                                          D10_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-27989
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-31239
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-35362
#
#                                      D_10_Annulation  \
# 0  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 1  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 2  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
#
#                  D_10_01_Annulation_Annonceanterieur  \
# 0  {'REFERENCE': {'IDWEB': '23-9111', 'TYPE_AVIS'...
# 1  {'REFERENCE': {'IDWEB': '23-29942', 'TYPE_AVIS...
# 2  {'REFERENCE': {'IDWEB': '23-35154', 'TYPE_AVIS...
#
#                             D_10_02_Annulation_Motif  \
# 0  Des erreurs ont été constatées mettant en caus...
# 1  Erreur dans la dénomination du marché: inférie...
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_10_ANNULATION_2023_03_AP.csv', sep=';', low_memory=False, nrows=10)
# Out:
#   D10_IDWEB D10_DATEPARUTION  \
# 0  23-27989       2023-03-01
# 1  23-31239       2023-03-08
# 2  23-35362       2023-03-16
#
#                                          D10_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-27989
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-31239
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-35362
#
#                                      D_10_Annulation  \
# 0  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 1  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 2  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
#
#                  D_10_01_Annulation_Annonceanterieur  \
# 0  {'REFERENCE': {'IDWEB': '23-9111', 'TYPE_AVIS'...
# 1  {'REFERENCE': {'IDWEB': '23-29942', 'TYPE_AVIS...
# 2  {'REFERENCE': {'IDWEB': '23-35154', 'TYPE_AVIS...
#
#                             D_10_02_Annulation_Motif  \
# 0  Des erreurs ont été constatées mettant en caus...
# 1  Erreur dans la dénomination du marché: inférie...
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_10_ANNULATION_2023_03_AP.csv', sep=';', low_memory=False, nrows=10)
# Out:
#   D10_IDWEB D10_DATEPARUTION  \
# 0  23-27989       2023-03-01
# 1  23-31239       2023-03-08
# 2  23-35362       2023-03-16
#
#                                          D10_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-27989
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-31239
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-35362
#
#                                      D_10_Annulation  \
# 0  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 1  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 2  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
#
#                  D_10_01_Annulation_Annonceanterieur  \
# 0  {'REFERENCE': {'IDWEB': '23-9111', 'TYPE_AVIS'...
# 1  {'REFERENCE': {'IDWEB': '23-29942', 'TYPE_AVIS...
# 2  {'REFERENCE': {'IDWEB': '23-35154', 'TYPE_AVIS...
#
#                             D_10_02_Annulation_Motif  \
# 0  Des erreurs ont été constatées mettant en caus...
# 1  Erreur dans la dénomination du marché: inférie...
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_10_ANNULATION_2023_03_AP.csv', sep=';', low_memory=False, nrows=10)
# Out:
#   D10_IDWEB D10_DATEPARUTION  \
# 0  23-27989       2023-03-01
# 1  23-31239       2023-03-08
# 2  23-35362       2023-03-16
#
#                                          D10_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-27989
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-31239
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-35362
#
#                                      D_10_Annulation  \
# 0  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 1  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 2  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
#
#                  D_10_01_Annulation_Annonceanterieur  \
# 0  {'REFERENCE': {'IDWEB': '23-9111', 'TYPE_AVIS'...
# 1  {'REFERENCE': {'IDWEB': '23-29942', 'TYPE_AVIS...
# 2  {'REFERENCE': {'IDWEB': '23-35154', 'TYPE_AVIS...
#
#                             D_10_02_Annulation_Motif  \
# 0  Des erreurs ont été constatées mettant en caus...
# 1  Erreur dans la dénomination du marché: inférie...
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_10_ANNULATION_2023_03_AP.csv', sep=';', low_memory=False, nrows=10)
# Out:
#   D10_IDWEB D10_DATEPARUTION  \
# 0  23-27989       2023-03-01
# 1  23-31239       2023-03-08
# 2  23-35362       2023-03-16
#
#                                          D10_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-27989
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-31239
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-35362
#
#                                      D_10_Annulation  \
# 0  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 1  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 2  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
#
#                  D_10_01_Annulation_Annonceanterieur  \
# 0  {'REFERENCE': {'IDWEB': '23-9111', 'TYPE_AVIS'...
# 1  {'REFERENCE': {'IDWEB': '23-29942', 'TYPE_AVIS...
# 2  {'REFERENCE': {'IDWEB': '23-35154', 'TYPE_AVIS...
#
#                             D_10_02_Annulation_Motif  \
# 0  Des erreurs ont été constatées mettant en caus...
# 1  Erreur dans la dénomination du marché: inférie...
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_10_ANNULATION_2023_03_AP.csv', sep=';', low_memory=False, nrows=10)
# Out:
#   D10_IDWEB D10_DATEPARUTION  \
# 0  23-27989       2023-03-01
# 1  23-31239       2023-03-08
# 2  23-35362       2023-03-16
#
#                                          D10_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-27989
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-31239
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-35362
#
#                                      D_10_Annulation  \
# 0  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 1  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 2  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
#
#                  D_10_01_Annulation_Annonceanterieur  \
# 0  {'REFERENCE': {'IDWEB': '23-9111', 'TYPE_AVIS'...
# 1  {'REFERENCE': {'IDWEB': '23-29942', 'TYPE_AVIS...
# 2  {'REFERENCE': {'IDWEB': '23-35154', 'TYPE_AVIS...
#
#                             D_10_02_Annulation_Motif  \
# 0  Des erreurs ont été constatées mettant en caus...
# 1  Erreur dans la dénomination du marché: inférie...
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_10_ANNULATION_2023_03_AP.csv', sep=';', low_memory=False, nrows=10)
# Out:
#   D10_IDWEB D10_DATEPARUTION  \
# 0  23-27989       2023-03-01
# 1  23-31239       2023-03-08
# 2  23-35362       2023-03-16
#
#                                          D10_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-27989
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-31239
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-35362
#
#                                      D_10_Annulation  \
# 0  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 1  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 2  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
#
#                  D_10_01_Annulation_Annonceanterieur  \
# 0  {'REFERENCE': {'IDWEB': '23-9111', 'TYPE_AVIS'...
# 1  {'REFERENCE': {'IDWEB': '23-29942', 'TYPE_AVIS...
# 2  {'REFERENCE': {'IDWEB': '23-35154', 'TYPE_AVIS...
#
#                             D_10_02_Annulation_Motif  \
# 0  Des erreurs ont été constatées mettant en caus...
# 1  Erreur dans la dénomination du marché: inférie...
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_10_ANNULATION_2023_03_AP.csv', sep=';', low_memory=False, nrows=10)
# Out:
#   D10_IDWEB D10_DATEPARUTION  \
# 0  23-27989       2023-03-01
# 1  23-31239       2023-03-08
# 2  23-35362       2023-03-16
#
#                                          D10_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-27989
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-31239
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-35362
#
#                                      D_10_Annulation  \
# 0  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 1  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 2  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
#
#                  D_10_01_Annulation_Annonceanterieur  \
# 0  {'REFERENCE': {'IDWEB': '23-9111', 'TYPE_AVIS'...
# 1  {'REFERENCE': {'IDWEB': '23-29942', 'TYPE_AVIS...
# 2  {'REFERENCE': {'IDWEB': '23-35154', 'TYPE_AVIS...
#
#                             D_10_02_Annulation_Motif  \
# 0  Des erreurs ont été constatées mettant en caus...
# 1  Erreur dans la dénomination du marché: inférie...
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_10_ANNULATION_2023_03_AP.csv', sep=';', low_memory=False, nrows=10)
# Out:
#   D10_IDWEB D10_DATEPARUTION  \
# 0  23-27989       2023-03-01
# 1  23-31239       2023-03-08
# 2  23-35362       2023-03-16
#
#                                          D10_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-27989
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-31239
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-35362
#
#                                      D_10_Annulation  \
# 0  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 1  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 2  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
#
#                  D_10_01_Annulation_Annonceanterieur  \
# 0  {'REFERENCE': {'IDWEB': '23-9111', 'TYPE_AVIS'...
# 1  {'REFERENCE': {'IDWEB': '23-29942', 'TYPE_AVIS...
# 2  {'REFERENCE': {'IDWEB': '23-35154', 'TYPE_AVIS...
#
#                             D_10_02_Annulation_Motif  \
# 0  Des erreurs ont été constatées mettant en caus...
# 1  Erreur dans la dénomination du marché: inférie...
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_10_ANNULATION_2023_03_AP.csv', sep=';', low_memory=False, nrows=10)
# Out:
#   D10_IDWEB D10_DATEPARUTION  \
# 0  23-27989       2023-03-01
# 1  23-31239       2023-03-08
# 2  23-35362       2023-03-16
#
#                                          D10_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-27989
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-31239
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-35362
#
#                                      D_10_Annulation  \
# 0  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 1  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 2  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
#
#                  D_10_01_Annulation_Annonceanterieur  \
# 0  {'REFERENCE': {'IDWEB': '23-9111', 'TYPE_AVIS'...
# 1  {'REFERENCE': {'IDWEB': '23-29942', 'TYPE_AVIS...
# 2  {'REFERENCE': {'IDWEB': '23-35154', 'TYPE_AVIS...
#
#                             D_10_02_Annulation_Motif  \
# 0  Des erreurs ont été constatées mettant en caus...
# 1  Erreur dans la dénomination du marché: inférie...
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_10_ANNULATION_2023_03_AP.csv', sep=';', low_memory=False, nrows=10)
# Out:
#   D10_IDWEB D10_DATEPARUTION  \
# 0  23-27989       2023-03-01
# 1  23-31239       2023-03-08
# 2  23-35362       2023-03-16
#
#                                          D10_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-27989
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-31239
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-35362
#
#                                      D_10_Annulation  \
# 0  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 1  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 2  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
#
#                  D_10_01_Annulation_Annonceanterieur  \
# 0  {'REFERENCE': {'IDWEB': '23-9111', 'TYPE_AVIS'...
# 1  {'REFERENCE': {'IDWEB': '23-29942', 'TYPE_AVIS...
# 2  {'REFERENCE': {'IDWEB': '23-35154', 'TYPE_AVIS...
#
#                             D_10_02_Annulation_Motif  \
# 0  Des erreurs ont été constatées mettant en caus...
# 1  Erreur dans la dénomination du marché: inférie...
# ...

# %%
pd.read_csv('https://www.aufilduboamp.com/partages/AUFILDUBOAMP_INTEGRALE_MARS_2023_CSV/D_10_ANNULATION_2023_03_AP.csv', sep=';', low_memory=False, nrows=10)
# Out:
#   D10_IDWEB D10_DATEPARUTION  \
# 0  23-27989       2023-03-01
# 1  23-31239       2023-03-08
# 2  23-35362       2023-03-16
#
#                                          D10_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-27989
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-31239
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-35362
#
#                                      D_10_Annulation  \
# 0  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 1  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
# 2  {'ANNONCE_ANTERIEUR': {'REFERENCE': {'IDWEB': ...
#
#                  D_10_01_Annulation_Annonceanterieur  \
# 0  {'REFERENCE': {'IDWEB': '23-9111', 'TYPE_AVIS'...
# 1  {'REFERENCE': {'IDWEB': '23-29942', 'TYPE_AVIS...
# 2  {'REFERENCE': {'IDWEB': '23-35154', 'TYPE_AVIS...
#
#                             D_10_02_Annulation_Motif  \
# 0  Des erreurs ont été constatées mettant en caus...
# 1  Erreur dans la dénomination du marché: inférie...
# ...
