# %% [markdown]
# <a href="https://colab.research.google.com/github/AuFilDuBoamp/partages/blob/main/CHARGEMENTS_TABLES_AFDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CHARGEMENTS

# %%
# Avoids scroll-in-the-scroll in the entire Notebook
from IPython.display import Javascript
def resize_colab_cell():
  display(Javascript('google.colab.output.setIframeHeight(0, true, {maxHeight: 5000})'))
get_ipython().events.register('pre_run_cell', resize_colab_cell)

# %%
import pandas as pd
pd.options.display.max_rows = 50
pd.options.display.max_columns = 50
pd.options.display.max_colwidth = 300

# %%
df_csv_git = pd.read_csv('https://raw.githubusercontent.com/AuFilDuBoamp/partages/main/aufilduboamp_liens_telechargements_direct_des_tables_2023_datagouv.csv', sep=',')
df_csv_git
# Out:
#                                nom_table_boamp  \
# 0                                A_00_Panorama
# 1                    B_01_Annonces_anterieures
# 2                                D_01_Identite
# 3                          D_02_Type_organisme
# 4               D_03_Type_pouvoir_adjudicateur
# 5                     D_04_Activite_principale
# 6                           D_05_Objet T1 2023
# 7                           D_05_Objet T2 2023
# 8                               D_06_Procedure
# 9                  D_07_Publication_anterieure
# 10                            D_08_Attribution
# 11                                 D_09_Rectif
# 12                             D_10_Annulation
# 13                        D_11_Condition_delai
# 14              D_12_Condition_relative_marche
# 15                D_13_Condition_participation
# 16  D_14_Condition_participation_systme_qualif
# 17               D_15_Condition_administrative
# 18         D_16_Renseignements_complementaires
# ...

# %% [markdown]
# Chargements

# %%
for row in df_csv_git.head().itertuples():
  try:
    print(f"df{row.nom_table_boamp} = pd.read_csv('{row.lien_telechargement_datagouv_2023}', low_memory=False, sep=';', chunksize=10)")
    print(f'next(row.nom_table_boamp).head()')
    print('\n'*1)

  except Exception as e:
    print(e)
    continue
# Out:
# dfA_00_Panorama = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/b409c71a-6919-4517-b165-3412ff55b50e', low_memory=False, sep=';', chunksize=10)
# next(row.nom_table_boamp).head()
#
#
# dfB_01_Annonces_anterieures = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/cd44f3ba-62be-4864-b3d5-39983f075f9c', low_memory=False, sep=';', chunksize=10)
# next(row.nom_table_boamp).head()
#
#
# dfD_01_Identite = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/b26bc9f1-0633-4d02-82f7-501835c4ddf1', low_memory=False, sep=';', chunksize=10)
# next(row.nom_table_boamp).head()
#
#
# dfD_02_Type_organisme = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/b915098d-00cc-47e4-98f6-21af512534b1', low_memory=False, sep=';', chunksize=10)
# next(row.nom_table_boamp).head()
#
#
# dfD_03_Type_pouvoir_adjudicateur = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/77db6d60-a195-4fc3-a700-b508f31cc95e', low_memory=False, sep=';', chunksize=10)
# next(row.nom_table_boamp).head()

# %%
dfA_00_Panorama = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/b409c71a-6919-4517-b165-3412ff55b50e', low_memory=False, sep=';', chunksize=10)
next(row.nom_table_boamp).head()


dfB_01_Annonces_anterieures = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/cd44f3ba-62be-4864-b3d5-39983f075f9c', low_memory=False, sep=';', chunksize=10)
next(row.nom_table_boamp).head()


dfD_01_Identite = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/b26bc9f1-0633-4d02-82f7-501835c4ddf1', low_memory=False, sep=';', chunksize=10)
next(row.nom_table_boamp).head()


dfD_02_Type_organisme = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/b915098d-00cc-47e4-98f6-21af512534b1', low_memory=False, sep=';', chunksize=10)
next(row.nom_table_boamp).head()


dfD_03_Type_pouvoir_adjudicateur = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/77db6d60-a195-4fc3-a700-b508f31cc95e', low_memory=False, sep=';', chunksize=10)
next(row.nom_table_boamp).head()

# %% [markdown]
# |Précisions sur les CSV|
# |:---------------|
# |Les données CSV sont séparées par des point-virgules (comme le BOAMP original).|
# |Le codage est universel (UTF-8).|
# |Les décimales sont signifiées par des points.|
# |Les données originales proviennent de l'API du BOAMP : [https://boamp-datadila.opendatasoft.com/explore/dataset/boamp/export/?q=dateparution:2023](https://boamp-datadila.opendatasoft.com/explore/dataset/boamp/export/?q=dateparution:2023).|
# |Permalien ► https://www.data.gouv.fr/fr/datasets/647f0a5f933232d8f6062abd/|
# |Notice (bientôt) ► https://www.aufilduboamp.com/article31.html|
# |Archives 2015-2023 en vente dans la Boutique AuFilDuBoamp ► https://www.aufilduboamp.com/article2.html#outil_sommaire_1|
# |Rappel: les données sont sous licence Etalab 2.0|
# |Sur Gcolabs ► https://colab.research.google.com/drive/1S41aBcm2IBH7BuBQi62gvGyS0tnLB0Tz?usp=sharing|
# |Permalien Github ► https://github.com/AuFilDuBoamp/partages/blob/be4ec1d312486b47f2cd5ba6a9f0d89c071b7116/AuFilDuBoamp_Table_A_00_Panorama_(pr%C3%A9chargement).ipynb|

# %% [markdown]
# ## Importation de la bibliothèque Pandas et quelques réglages

# %%
import pandas as pd
pd.options.display.max_rows = 50
pd.options.display.max_columns = 50
pd.options.display.max_colwidth = 300

# %%
dfA_00_Panorama = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/b409c71a-6919-4517-b165-3412ff55b50e', low_memory=False, sep=';', chunksize=10)

# %%
next(dfA_00_Panorama).head()
# Out:
#   P_01_Annoncelie  P_02_Annoncereferenceschemav110  \
# 0        22-23470                              NaN
# 1             NaN                              NaN
# 2       22-109340                              NaN
# 3        22-45441                              NaN
# 4             NaN                              NaN
#
#    P_03_Annoncesanterieuresschemav110 P_04_Codedepartement  \
# 0                                 NaN                   64
# 1                                 NaN                   56
# 2                                 NaN                   17
# 3                                 NaN                21,52
# 4                                 NaN                   75
#
#    P_05_Codedepartementprestation             P_06_Criteres  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# ...

# %% [markdown]
# ## Importation des données et création du dataframe

# %%
PERMALIEN_DATAGOUV_PANORAMA_2023_CSV = 'https://www.data.gouv.fr/fr/datasets/r/b409c71a-6919-4517-b165-3412ff55b50e'
df = pd.read_csv(PERMALIEN_DATAGOUV_PANORAMA_2023_CSV, sep=';', low_memory=False)

# %% [markdown]
# ## Infos générales sur le dataframe

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126973 entries, 0 to 126972
# Data columns (total 39 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   P_01_Annoncelie                     43515 non-null   object
#  1   P_02_Annoncereferenceschemav110     0 non-null       float64
#  2   P_03_Annoncesanterieuresschemav110  0 non-null       float64
#  3   P_04_Codedepartement                126921 non-null  object
#  4   P_05_Codedepartementprestation      0 non-null       float64
#  5   P_06_Criteres                       36680 non-null   object
#  6   P_07_Datefindiffusion               126973 non-null  object
#  7   P_08_Datelimitereponse              43235 non-null   object
#  8   P_09_Dateparution                   126973 non-null  object
#  9   P_10_Dc                             126805 non-null  object
#  10  P_11_Descripteurcode                126805 non-null  object
# ...

# %% [markdown]
# ## Les premières lignes du tableau

# %%
df.head()
# Out:
#   P_01_Annoncelie  P_02_Annoncereferenceschemav110  \
# 0        22-23470                              NaN
# 1             NaN                              NaN
# 2       22-109340                              NaN
# 3        22-45441                              NaN
# 4             NaN                              NaN
#
#    P_03_Annoncesanterieuresschemav110 P_04_Codedepartement  \
# 0                                 NaN                   64
# 1                                 NaN                   56
# 2                                 NaN                   17
# 3                                 NaN                21,52
# 4                                 NaN                   75
#
#    P_05_Codedepartementprestation             P_06_Criteres  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# ...

# %% [markdown]
# # À vous de jouer!

# %%
df.P_09_Dateparution.max()
# Out:
# '2023-06-19'
