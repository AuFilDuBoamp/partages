# %% [markdown]
# <a href="https://colab.research.google.com/github/AuFilDuBoamp/partages/blob/main/CHARGEMENTS_TABLES_AFDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CHARGEMENTS

# %%
import pandas as pd

# %%
# @title
df_csv_git = pd.read_csv('https://raw.githubusercontent.com/AuFilDuBoamp/partages/main/aufilduboamp_liens_telechargements_direct_des_tables_2023_datagouv.csv', sep=',')
df_csv_git.head()
# Out:
#                   nom_table_boamp  \
# 0                   A_00_Panorama
# 1       B_01_Annonces_anterieures
# 2                   D_01_Identite
# 3             D_02_Type_organisme
# 4  D_03_Type_pouvoir_adjudicateur
#
#                    lien_telechargement_datagouv_2023
# 0  https://www.data.gouv.fr/fr/datasets/r/b409c71...
# 1  https://www.data.gouv.fr/fr/datasets/r/cd44f3b...
# 2  https://www.data.gouv.fr/fr/datasets/r/b26bc9f...
# 3  https://www.data.gouv.fr/fr/datasets/r/b915098...
# 4  https://www.data.gouv.fr/fr/datasets/r/77db6d6...

# %% [markdown]
# Chargements

# %%
for row in df_csv_git.itertuples():
  try:
    print(f"""df{row.nom_table_boamp} = pd.read_csv('{row.lien_telechargement_datagouv_2023}',
          low_memory=False, sep=';', chunksize=2)""")
    print('\n'*1)
    print(f"display(next(df{row.nom_table_boamp}))")
    print('\n'*1)

  except Exception as e:
    print(e)
    continue
# Out:
# dfA_00_Panorama = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/b409c71a-6919-4517-b165-3412ff55b50e',
#           low_memory=False, sep=';', chunksize=2)
#
#
# display(next(dfA_00_Panorama))
#
#
# dfB_01_Annonces_anterieures = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/cd44f3ba-62be-4864-b3d5-39983f075f9c',
#           low_memory=False, sep=';', chunksize=2)
#
#
# display(next(dfB_01_Annonces_anterieures))
#
#
# dfD_01_Identite = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/b26bc9f1-0633-4d02-82f7-501835c4ddf1',
#           low_memory=False, sep=';', chunksize=2)
#
#
# display(next(dfD_01_Identite))
#
#
# dfD_02_Type_organisme = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/b915098d-00cc-47e4-98f6-21af512534b1',
#           low_memory=False, sep=';', chunksize=2)
#
#
# display(next(dfD_02_Type_organisme))
#
#
# dfD_03_Type_pouvoir_adjudicateur = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/77db6d60-a195-4fc3-a700-b508f31cc95e',
# ...

# %%
# @title
dfA_00_Panorama = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/b409c71a-6919-4517-b165-3412ff55b50e',
          low_memory=False, sep=';', chunksize=2)


display(next(dfA_00_Panorama))
# Out:
#   P_01_Annoncelie  P_02_Annoncereferenceschemav110  \
# 0        22-23470                              NaN
# 1             NaN                              NaN
#
#    P_03_Annoncesanterieuresschemav110  P_04_Codedepartement  \
# 0                                 NaN                    64
# 1                                 NaN                    56
#
#    P_05_Codedepartementprestation  P_06_Criteres P_07_Datefindiffusion  \
# 0                             NaN            NaN            2023-01-31
# 1                             NaN            NaN            2023-03-02
#
#    P_08_Datelimitereponse P_09_Dateparution  P_10_Dc  ...  P_30_Sousnature  \
# 0                     NaN        2023-01-01       69  ...         STANDARD
# 1                     NaN        2023-01-01       82  ...         STANDARD
#
#   P_31_Sousnaturelibelle P_32_Soustypeprocedure  \
# 0                    NaN                    NaN
# 1                    NaN                    NaN
#
# ...

# %%
dfB_01_Annonces_anterieures = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/cd44f3ba-62be-4864-b3d5-39983f075f9c',
          low_memory=False, sep=';', chunksize=2)


display(next(dfB_01_Annonces_anterieures))
# Out:
#   B_01_Annoncesanterieures B01_DATEPARUTION  B01_IDWEB  \
# 0                        +       2023-01-01  22-139142
# 1                        +       2023-01-01  22-139142
#
#                                          B01_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-13...
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-13...
#
#   B_01_01_Annoncesanterieures_Reference  \
# 0                                     +
# 1                                     +
#
#   B_01_02_Annoncesanterieures_Referencepublication  \
# 0                                                +
# 1                                                +
#
#   B_01_01_02_Annoncesanterieures_Reference_Idweb  \
# 0                                       22-23470
# 1                                       22-23470
#
#   B_01_01_03_Annoncesanterieures_Reference_Typeavis  \
# 0                                                 +
# 1                                                 +
#
# ...

# %%
dfD_01_Identite = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/b26bc9f1-0633-4d02-82f7-501835c4ddf1',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_01_Identite))
# Out:
#    D01_IDWEB D01_DATEPARUTION  \
# 0  22-139142       2023-01-01
# 1  22-156401       2023-01-01
#
#                                          D01_URLAVIS D_01_Identite  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-13...             +
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-15...             +
#
#   D_01_01_Identite_Adjudicateurnuts  D_01_02_Identite_Adresse  \
# 0                             FRI15                       NaN
# 1                             FRH04                       NaN
#
#    D_01_03_Identite_Agitpourautrecomptenon  \
# 0                                     True
# 1                                     True
#
#    D_01_04_Identite_Agitpourautrecompteoui  \
# 0                                    False
# 1                                    False
#
#    D_01_05_Identite_Autreaccesdocument  D_01_06_Identite_Codeidentnational  \
# 0                                  NaN                                 NaN
# ...

# %%
dfD_02_Type_organisme = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/b915098d-00cc-47e4-98f6-21af512534b1',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_02_Type_organisme))
# Out:
#   D02_DATEPARUTION D02_IDWEB  \
# 0       2023-01-02  22-65842
# 1       2023-01-02    23-122
#
#                                          D02_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-65842
# 1    https://www.boamp.fr/pages/avis/?q=idweb:23-122
#
#   D_02_01_Typeorganisme_Autre D_02_02_Typeorganisme_Commune  \
# 0                         NaN                     case_vide
# 1                   case_vide                           NaN
#
#    D_02_03_Typeorganisme_Departement  D_02_04_Typeorganisme_Epn  \
# 0                                NaN                        NaN
# 1                                NaN                        NaN
#
#    D_02_05_Typeorganisme_Ept  D_02_06_Typeorganisme_Etat  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
#
#    D_02_07_Typeorganisme_Institutioneuropeenne  D_02_08_Typeorganisme_Region  \
# ...

# %%
dfD_03_Type_pouvoir_adjudicateur = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/77db6d60-a195-4fc3-a700-b508f31cc95e',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_03_Type_pouvoir_adjudicateur))
# Out:
#   D03_DATEPARUTION  D03_IDWEB  \
# 0       2023-01-01  22-139142
# 1       2023-01-01  22-156401
#
#                                          D03_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-13...
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-15...
#
#    D_03_01_Typepouvoiradjudicateur_Agencenational  \
# 0                                             NaN
# 1                                             NaN
#
#    D_03_02_Typepouvoiradjudicateur_Agenceregional  \
# 0                                             NaN
# 1                                             NaN
#
#   D_03_03_Typepouvoiradjudicateur_Autotriteregional  \
# 0                                               NaN
# 1                                         case_vide
#
#   D_03_04_Typepouvoiradjudicateur_Autre  \
# 0         Etablissement public de santé
# 1                                   NaN
#
#    D_03_05_Typepouvoiradjudicateur_Institutioneuropeenne  \
# ...

# %%
dfD_04_Activite_principale = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/7361182d-ccf5-4499-b1d9-c86afc7eeb70',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_04_Activite_principale))
# Out:
#   D04_DATEPARUTION  D04_IDWEB  \
# 0       2023-01-01  22-139142
# 1       2023-01-01  22-156401
#
#                                          D04_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-13...
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-15...
#
#   D_04_01_01_Activiteprincipale_Entiteadjudicatrice_Actaeroport  \
# 0                                                NAN
# 1                                                NAN
#
#   D_04_01_02_Activiteprincipale_Entiteadjudicatrice_Actport  \
# 0                                                NAN
# 1                                                NAN
#
#   D_04_01_03_Activiteprincipale_Entiteadjudicatrice_Autre  \
# 0                                                NAN
# 1                                                NAN
#
#   D_04_01_04_Activiteprincipale_Entiteadjudicatrice_Eau  \
# 0                                                NAN
# 1                                                NAN
#
# ...

# %%
dfD_05_Objet_T1_2023 = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/529fc127-dae7-4557-a043-b4ee1e1d13c2',
          low_memory=False, sep=';', chunksize=2, compression='zip')


display(next(dfD_05_Objet_T1_2023))
# Out:
#   D05_DATEPARUTION  D05_IDWEB  \
# 0       2023-01-01  22-139142
# 1       2023-01-01  22-139142
#
#                                          D05_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-13...
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-13...
#
#   D_05_01_Objet_Accordcadre  D_05_02_Objet_Ampnon  D_05_03_Objet_Ampoui  \
# 0                         +                   NaN                   NaN
# 1                         +                   NaN                   NaN
#
#   D_05_04_Objet_Aviscorrespond D_05_05_Objet_Avisimplique  \
# 0                            +                          +
# 1                            +                          +
#
#   D_05_06_Objet_Caracteristiques D_05_07_Objet_Cpv  ...  \
# 0                              +                 +  ...
# 1                              +                 +  ...
#
#    D_05_25_03_Objet_Typemarche_Fournitures  \
# 0                                        +
# 1                                        +
# ...

# %%
dfD_05_Objet_T2_2023 = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/14c1c7fc-6f40-4027-ba8c-0d6c7d149248',
          low_memory=False, sep=';', chunksize=2, compression='zip')


display(next(dfD_05_Objet_T2_2023))
# Out:
#   D05_DATEPARUTION D05_IDWEB  \
# 0       2023-04-01  18-63718
# 1       2023-04-01  23-12316
#
#                                          D05_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:18-63718
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-12316
#
#   D_05_01_Objet_Accordcadre  D_05_02_Objet_Ampnon  D_05_03_Objet_Ampoui  \
# 0                         +                   NaN                   NaN
# 1                         +                   NaN                   NaN
#
#   D_05_04_Objet_Aviscorrespond D_05_05_Objet_Avisimplique  \
# 0                            +                          +
# 1                            +                          +
#
#   D_05_06_Objet_Caracteristiques D_05_07_Objet_Cpv  ...  \
# 0                              +                 +  ...
# 1                              +                 +  ...
#
#    D_05_25_03_Objet_Typemarche_Fournitures  \
# 0                                        +
# 1                                        +
#
# ...

# %%
dfD_06_Procedure = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/040e9f01-fc83-47b7-a72c-fa123792e9ab',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_06_Procedure))
# Out:
#    D06_IDWEB D06_DATEPARUTION  \
# 0  22-139142       2023-01-01
# 1  22-156401       2023-01-01
#
#                                          D06_URLAVIS D_06_Procedure  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-13...              +
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-15...              +
#
#   D_06_24_Procedure_Typeprocedure D_06_10_Procedure_Criteresattribution  \
# 0                               +                                     +
# 1                               +                                     +
#
#   D_06_13_Procedure_Enchereelectroniquenon  \
# 0                                case_vide
# 1                                case_vide
#
#    D_06_15_Procedure_Fondscommunautairesnon  \
# 0                                       NaN
# 1                                       NaN
#
#    D_06_19_Procedure_Marcheperiodiquenon D_06_22_Procedure_Nbcandidats  ...  \
# 0                                    NaN                             +  ...
# ...

# %%
dfD_07_Publication_anterieure = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/1d5f1e1d-6458-4606-a0a4-581182370703',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_07_Publication_anterieure))
# Out:
#    D07_IDWEB D07_DATEPARUTION  \
# 0  22-139142       2023-01-01
# 1  22-156401       2023-01-01
#
#                                          D07_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-13...
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-15...
#
#   D_07_Publicationanterieure  D_07_01_Publicationanterieure_Non  \
# 0                          +                                NaN
# 1                          +                                NaN
#
#   D_07_02_Publicationanterieure_Oui  \
# 0                         case_vide
# 1                         case_vide
#
#   D_07_03_Publicationanterieure_Referencepublication  \
# 0                                                  +
# 1                                                  +
#
#   D_07_03_01_Publicationanterieure_Referencepublication_Publicationjoue  \
# 0                                                  +
# 1                                                  +
#
# ...

# %%
dfD_08_Attribution = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/eb9f62fb-4645-4330-b1db-9ecf076a9f55',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_08_Attribution))
# Out:
#    D08_IDWEB D08_DATEPARUTION  \
# 0  22-139142       2023-01-01
# 1  22-139142       2023-01-01
#
#                                          D08_URLAVIS D_08_Attribution  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-13...                +
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-13...                +
#
#    D_08_01_Attribution_Attribuecomportelotinfructueux  \
# 0                                              False
# 1                                              False
#
#    D_08_02_Attribution_Attribueparlotsmarches  \
# 0                                       False
# 1                                       False
#
#    D_08_03_Attribution_Datedecision D_08_04_Attribution_Decision  \
# 0                               NaN                            +
# 1                               NaN                            +
#
#   D_08_05_Attribution_Offrebasse D_08_06_Attribution_Offreelevee  ...  \
# 0                              +                               +  ...
# ...

# %%
dfD_09_Rectif = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/7143d176-136e-4ada-a631-ad01ec337dcd',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_09_Rectif))
# Out:
#    D09_IDWEB D09_DATEPARUTION  \
# 0  22-171714       2023-01-01
# 1  22-171714       2023-01-01
#
#                                          D09_URLAVIS D_09_Rectif  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-17...           +
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-17...           +
#
#   D_09_01_Rectif_Annonceanterieur  D_09_02_Rectif_Infocomplementaire  \
# 0                               +                                NaN
# 1                               +                                NaN
#
#   D_09_03_Rectif_Modification D_09_01_01_Rectif_Annonceanterieur_Reference  \
# 0                           +                                            +
# 1                           +                                            +
#
#   D_09_01_02_Rectif_Annonceanterieur_Referencepublication  \
# 0                                                  +
# 1                                                  +
#
# ...

# %%
dfD_10_Annulation = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/f209ded3-d7a4-4f90-87ab-5d7097e65bf2',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_10_Annulation))
# Out:
#   D10_IDWEB D10_DATEPARUTION  \
# 0   23-1676       2023-01-04
# 1   23-4768       2023-01-11
#
#                                         D10_URLAVIS D_10_Annulation  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-1676               +
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-4768               +
#
#   D_10_01_Annulation_Annonceanterieur D_10_02_Annulation_Motif  \
# 0                                   +  Motif d'intérêt général
# 1                                   +       Erreur publication
#
#   D_10_01_01_Annulation_Annonceanterieur_Reference  \
# 0                                                +
# 1                                                +
#
#   D_10_01_02_Annulation_Annonceanterieur_Referencepublication  \
# 0                                                  +
# 1                                                  +
#
#   D_10_01_01_01_Annulation_Annonceanterieur_Reference_Idweb  \
# 0                                           22-91989
# ...

# %%
dfD_11_Condition_delai = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/64c28578-aa29-4d8d-a33c-5b1993840d88',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_11_Condition_delai))
# Out:
#    D11_IDWEB D11_DATEPARUTION  \
# 0  22-171207       2023-01-01
# 1  22-171330       2023-01-01
#
#                                          D11_URLAVIS D_11_Conditiondelai  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-17...                   +
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-17...                   +
#
#   D_11_01_Conditiondelai_Dureesystemequalification  \
# 0                                                +
# 1                                                +
#
#    D_11_02_Conditiondelai_Limiteenvoiinvit  \
# 0                                      NaN
# 1                                      NaN
#
#    D_11_03_Conditiondelai_Receptcandidat D_11_04_Conditiondelai_Receptoffres  \
# 0                                    NaN           2023-02-07T12:00:00+01:00
# 1                                    NaN           2023-01-31T12:00:00+01:00
#
#   D_11_05_Conditiondelai_Validiteoffre  \
# 0                                    +
# ...

# %%
dfD_12_Condition_relative_marche = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/9ad613d7-5fda-4342-bf99-b93533adb2e3',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_12_Condition_relative_marche))
# Out:
#    D12_IDWEB D12_DATEPARUTION  \
# 0  22-171207       2023-01-01
# 1  22-171330       2023-01-01
#
#                                          D12_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-17...
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-17...
#
#   D_12_Conditionrelativemarche  \
# 0                            +
# 1                            +
#
#   D_12_01_Conditionrelativemarche_Autresconditionspartnon  \
# 0                                          case_vide
# 1                                                NaN
#
#    D_12_02_Conditionrelativemarche_Autresconditionspartoui  \
# 0                                                NaN
# 1                                                NaN
#
#    D_12_03_Conditionrelativemarche_Cautionnement  \
# 0                                            NaN
# 1                                            NaN
#
#    D_12_04_Conditionrelativemarche_Financement  \
# 0                                          NaN
# ...

# %%
dfD_13_Condition_participation = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/b91488dc-cd51-4984-9716-251576771f09',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_13_Condition_participation))
# Out:
#    D13_IDWEB D13_DATEPARUTION  \
# 0  22-171207       2023-01-01
# 1  22-171330       2023-01-01
#
#                                          D13_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-17...
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-17...
#
#   D_13_Conditionparticipation  D_13_01_Conditionparticipation_Capeco  \
# 0                           +                                    NaN
# 1                           +                                    NaN
#
#   D_13_02_Conditionparticipation_Capecomarchenon  \
# 0                                            NaN
# 1                                      case_vide
#
#   D_13_03_Conditionparticipation_Capecomarcheoui  \
# 0                                      case_vide
# 1                                            NaN
#
#    D_13_04_Conditionparticipation_Capeconiveaumini  \
# 0                                              NaN
# 1                                              NaN
#
# ...

# %%
dfD_14_Condition_participation_systme_qualif = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/573164ce-e230-4ad6-9b4c-cc53f0de3953',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_14_Condition_participation_systme_qualif))
# Out:
#   D14_IDWEB D14_DATEPARUTION  \
# 0   21-3712       2021-01-11
# 1   21-3794       2021-01-11
#
#                                         D14_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:21-3712
# 1  https://www.boamp.fr/pages/avis/?q=idweb:21-3794
#
#   D_14_Conditionparticipationsystmequalif  \
# 0                                       +
# 1                                       +
#
#   D_14_01_Conditionparticipationsystmequalif_Conditions  \
# 0  Conditions énoncées dans le règlement de consu...
# 1  Clauses environnementales :Pour concourir, le ...
#
#    D_14_02_Conditionparticipationsystmequalif_Methodeverification
# 0                                                NaN
# 1                                                NaN

# %%
dfD_15_Condition_administrative = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/08f1fc35-6ac9-4bc8-a5aa-910191ab970b',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_15_Condition_administrative))
# Out:
#    D15_IDWEB D15_DATEPARUTION  \
# 0  22-139142       2023-01-01
# 1  22-156401       2023-01-01
#
#                                          D15_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-13...
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-15...
#
#   D_15_Conditionadministrative D_15_01_Conditionadministrative_Abandonsadnon  \
# 0                            +                                     case_vide
# 1                            +                                     case_vide
#
#    D_15_02_Conditionadministrative_Abandonsadoui  \
# 0                                            NaN
# 1                                            NaN
#
#    D_15_03_Conditionadministrative_Conditionsetmodepaiementobtenirdocuments  \
# 0                                                NaN
# 1                                                NaN
#
#    D_15_04_Conditionadministrative_Conditionsremiseoffres  \
# 0                                                NaN
# ...

# %%
dfD_16_Renseignements_complementaires = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/4c2746ad-a07a-48e9-8151-293ebb798f79',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_16_Renseignements_complementaires))
# Out:
#    D16_IDWEB D16_DATEPARUTION  \
# 0  22-139142       2023-01-01
# 1  22-139142       2023-01-01
#
#                                          D16_URLAVIS  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-13...
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-13...
#
#   D_16_Renseignementscomplementaires  \
# 0                                  +
# 1                                  +
#
#   D_16_01_Renseignementscomplementaires_Adressescomplementaires  \
# 0                                                  +
# 1                                                  +
#
#    D_16_02_Renseignementscomplementaires_Commandeelectroniquenon  \
# 0                                                NaN
# 1                                                NaN
#
#    D_16_03_Renseignementscomplementaires_Commandeelectroniqueoui  \
# 0                                                NaN
# 1                                                NaN
#
# ...

# %%
dfD_17_Modif = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/7ad32935-d782-4da7-a714-a19c447a81bd',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_17_Modif))
# Out:
#    D17_IDWEB D17_DATEPARUTION  \
# 0  22-172035       2023-01-01
# 1  22-172035       2023-01-01
#
#                                          D17_URLAVIS D_17_Modif  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-17...          +
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-17...          +
#
#   D_17_03_Modif_Cpv D_17_02_Modif_Codenuts  \
# 0                 +                  FRJ13
# 1                 +                  FRJ13
#
#                            D_17_06_Modif_Description  D_17_05_Modif_Datefin  \
# 0  FOURNITURE DE PRODUITS EN TEXTURES MODIFIEES P...                    NaN
# 1  FOURNITURE DE PRODUITS EN TEXTURES MODIFIEES P...                    NaN
#
#   D_17_14_Modif_Valeur D_17_13_Modif_Titulaire  ...  \
# 0                    +                       +  ...
# 1                    +                       +  ...
#
#   D_17_13_07_Modif_Titulaire_Mel D_17_13_08_Modif_Titulaire_Pays  \
# 0                            NaN                              FR
# ...

# %%
dfD_18_Annexed1 = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/c7b7564d-5f07-4885-a75b-46d34df7ae7d',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_18_Annexed1))
# Out:
#    D18_IDWEB D18_DATEPARUTION  \
# 0  22-171948       2023-01-01
# 1  22-172025       2023-01-01
#
#                                          D18_URLAVIS D_18_Annexed1  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-17...             +
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-17...             +
#
#    D_18_06_Annexed1_Marchecomplementaire  \
# 0                                    NaN
# 1                                    NaN
#
#                         D_18_01_Annexed1_Explication  \
# 0  Il s'agit d'une seconde procédure sans publici...
# 1  Le présent marché est un marché de travaux à p...
#
#    D_18_09_Annexed1_Proprieteintellectuelle  \
# 0                                       NaN
# 1                                       NaN
#
#   D_18_03_Annexed1_Infructueuxouverte D_18_11_Annexed1_Raisonstechniques  \
# 0                           case_vide                                NaN
# 1                                 NaN                          case_vide
#
# ...

# %%
dfD_19_Annexed2 = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/4771831c-9cf8-4348-b847-042bcfd22774',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_19_Annexed2))
# Out:
#   D19_IDWEB D19_DATEPARUTION  \
# 0   23-1839       2023-01-07
# 1   23-4759       2023-01-13
#
#                                         D19_URLAVIS D_19_Annexed2  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-1839             +
# 1  https://www.boamp.fr/pages/avis/?q=idweb:23-4759             +
#
#    D_19_09_Annexed2_Raisonstechniques  \
# 0                                 NaN
# 1                                 NaN
#
#                         D_19_01_Annexed2_Explication  \
# 0  Ce contrat relève du champ d'application de la...
# 1  Thalès a fourni une attestation d'exclusivité ...
#
#   D_19_07_Annexed2_Proprieteintellectuelle D_19_02_Annexed2_Horsscope  \
# 0                                      NaN                  case_vide
# 1                                case_vide                        NaN
#
#    D_19_03_Annexed2_Infructueux  D_19_10_Annexed2_Recherche  \
# 0                           NaN                         NaN
# ...

# %%
dfD_20_Annexed3 = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/74ef74f9-b73d-41cf-81ee-b73a08823616',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_20_Annexed3))
# Out:
#   D20_IDWEB D20_DATEPARUTION  \
# 0  21-45514       2021-04-09
# 1  21-59776       2021-06-09
#
#                                          D20_URLAVIS D_20_Annexed3  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:21-45514             +
# 1  https://www.boamp.fr/pages/avis/?q=idweb:21-59776             +
#
#   D_20_02_Annexed3_Horsscope  \
# 0                  case_vide
# 1                  case_vide
#
#                         D_20_01_Annexed3_Explication  \
# 0  Considérant que les marchés peuvent être sans ...
# 1  En vertu des directives 2014/24/UE du Parlemen...
#
#    D_20_03_Annexed3_Proprieteintellectuelle  D_20_04_Annexed3_Serviceslistes
# 0                                       NaN                              NaN
# 1                                       NaN                              NaN

# %%
dfD_21_Annexed4 = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/f2e2048d-4aea-4501-8db2-ced4f85467e9',
          low_memory=False, sep=';', chunksize=2)


display(next(dfD_21_Annexed4))
# Out:
#   D21_IDWEB D21_DATEPARUTION                                      D21_URLAVIS  \
# 0    23-470       2023-01-03  https://www.boamp.fr/pages/avis/?q=idweb:23-470
# 1    23-819       2023-01-05  https://www.boamp.fr/pages/avis/?q=idweb:23-819
#
#   D_21_Annexed4 D_21_02_Annexed4_Horsscope  \
# 0             +                        NaN
# 1             +                  case_vide
#
#                         D_21_01_Annexed4_Explication  \
# 0  Le contrat de concession prend effet le 01/01/...
# 1     Procédure en dessous des seuils réglementaires
#
#    D_21_05_Annexed4_Raisonsartistiques  D_21_06_Annexed4_Raisonsexclusivites  \
# 0                                  NaN                                   NaN
# 1                                  NaN                                   NaN
#
#   D_21_07_Annexed4_Raisonstechniques  D_21_03_Annexed4_Infructueux  \
# 0                          case_vide                           NaN
# ...

# %%
dfG_01_Reference = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/7af73fca-8b95-4233-9a9c-56df671e57cc',
          low_memory=False, sep=';', chunksize=2)


display(next(dfG_01_Reference))
# Out:
#    G01_IDWEB G01_DATEPARUTION  \
# 0  22-139142       2023-01-01
# 1  22-156401       2023-01-01
#
#                                          G01_URLAVIS G_01_Reference  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-13...              +
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-15...              +
#
#   G_01_01_Reference_Typeavis G_01_02_Reference_Idweb  \
# 0                          +               22-139142
# 1                          +               22-156401
#
#   G_01_01_03_Reference_Typeavis_Famille  \
# 0                                     +
# 1                                     +
#
#   G_01_01_04_Reference_Typeavis_Perimetre  \
# 0                                       +
# 1                                       +
#
#   G_01_01_02_Reference_Typeavis_Nature G_01_01_01_Reference_Typeavis_Statut  \
# 0                                    +                                    +
# 1                                    +                                    +
#
# ...

# %%
dfG_02_Marche = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/9aea47d2-a2ad-4630-a2ff-7e3ee4b0333b',
          low_memory=False, sep=';', chunksize=2)


display(next(dfG_02_Marche))
# Out:
#    G02_IDWEB G02_DATEPARUTION  \
# 0  22-139142       2023-01-01
# 1  22-139142       2023-01-01
#
#                                          G02_URLAVIS G_02_Marche  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-13...           +
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-13...           +
#
#   G_02_01_Marche_Annonceanterieur  G_02_02_Marche_Idconsultation  \
# 0                               +                            NaN
# 1                               +                            NaN
#
#    G_02_03_Marche_Urlconsultation  \
# 0                             NaN
# 1                             NaN
#
#   G_02_01_02_Marche_Annonceanterieur_Reference  \
# 0                                            +
# 1                                            +
#
#   G_02_01_01_Marche_Annonceanterieur_Referencepublication  \
# 0                                                  +
# 1                                                  +
#
# ...

# %% [markdown]
# ## dfG_03_Nomhtml (pas traité car redondant)

# %%
dfG_04_Indexation = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/d824e366-5ad6-49c3-826f-95ffbfcdba6a',
          low_memory=False, sep=';', chunksize=2)


display(next(dfG_04_Indexation))
# Out:
#    G04_IDWEB G04_DATEPARUTION  \
# 0  22-139142       2023-01-01
# 1  22-156401       2023-01-01
#
#                                          G04_URLAVIS G_04_Indexation  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:22-13...               +
# 1  https://www.boamp.fr/pages/avis/?q=idweb:22-15...               +
#
#   G_04_01_Indexation_Classes G_04_02_Indexation_Criteressociauxenv  \
# 0                          +                                     +
# 1                          +                                     +
#
#   G_04_03_Indexation_Datefindiffusion  G_04_04_Indexation_Datelimitereponse  \
# 0                          2023-01-31                                   NaN
# 1                          2023-03-02                                   NaN
#
#   G_04_05_Indexation_Datepublication  G_04_06_Indexation_Depprestation  ...  \
# 0                         2023-01-01                               NaN  ...
# ...

# %% [markdown]
# |Précisions sur les CSV|
# |:---------------|
# |Les données CSV sont séparées par des point-virgules (comme le BOAMP original).|
# |Le codage est universel (UTF-8).|
# |Les décimales sont signifiées par des points.|
# |Les données originales proviennent de l'API du BOAMP : [https://boamp-datadila.opendatasoft.com/explore/dataset/boamp/export/?q=dateparution:2023](https://boamp-datadila.opendatasoft.com/explore/dataset/boamp/export/?q=dateparution:2023).|
# |Rappel: les données sont sous licence Etalab 2.0|

# %%
# FIN
